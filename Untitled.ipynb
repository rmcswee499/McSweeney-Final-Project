# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
features_ls = ["5'_UTR","CDS","Exon","3'_UTR"]

# %%
for n_iter in range(len(features_ls)):
    pd.read_csv("data/{}_Feature_lengths.csv".format(features_ls[n_iter]),names=["Gene Name", "Length (nt)"])
# Out:
#         Gene Name  Length (nt)
# 0  Geneid\tLength          NaN
# 1      Myo81F\t78          NaN
# 2       spok\t108          NaN
# 3        Parp\t55          NaN
# 4      Alg-2\t682          NaN
