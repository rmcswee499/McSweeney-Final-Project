# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
features_ls = ["5'_UTR","CDS","Exon","3'_UTR","Gene"]

# %%
#for n_iter in range(len(features_ls)):
 #   features_ls_df = []
  #features_ls_df[n_iter] =  pd.read_csv("data/{}_Feature_lengths.csv".format(features_ls[n_iter]),names=["Gene Name", "Length (nt)"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 for n_iter in range(len(features_ls)):
#       2     features_ls_df = []
# ----> 3     features_ls_df[n_iter] =  pd.read_csv("data/{}_Feature_lengths.csv".format(features_ls[n_iter]),names=["Gene Name", "Length (nt)"])
#
# IndexError: list assignment index out of range

# %%
# Read counts and lengths for 5' UTR
length_5_UTR_df = pd.read_csv("data/{}_Feature_lengths.csv".format("5'_UTR"),names=["Gene Name", "Length (nt)"]) 
length_5_UTR_df.head() 

counts_5_UTR_df = pd.read_csv("data/{}_Counts.csv".format("5'_UTR"),names=["Gene Name", "Counts"]) 
counts_5_UTR_df.head()

# Read counts and lengths for 3' UTR
length_3_UTR_df = pd.read_csv("data/{}_Feature_lengths.csv".format("3'_UTR"),names=["Gene Name", "Length (nt)"]) 
length_3_UTR_df.head() 

counts_3_UTR_df = pd.read_csv("data/{}_Counts.csv".format("3'_UTR"),names=["Gene Name", "Counts"]) 
counts_3_UTR_df.head() 

# Read counts and lengths for Exons
length_exon_df = pd.read_csv("data/{}_Feature_lengths.csv".format("Exon"),names=["Gene Name", "Length (nt)"]) 
length_exon_df.head() 

counts_exon_df = pd.read_csv("data/{}_Counts.csv".format("Exon"),names=["Gene Name", "Counts"]) 
counts_exon_df.head() 

# Read counts and lengths by Gene
length_exon_df = pd.read_csv("data/{}_Feature_lengths.csv".format("Gene"),names=["Gene Name", "Length (nt)"]) 
length_exon_df.head() 

counts_exon_df = pd.read_csv("data/{}_Counts.csv".format("Gene"),names=["Gene Name", "Counts"]) 
counts_exon_df.head()
# Out:
#   Gene Name           Counts
# 0    Geneid  Nab2_ex3_F2.bam
# 1    Myo81F             2416
# 2   CR41571                0
# 3   CR12798                0
# 4   CR46123                0
